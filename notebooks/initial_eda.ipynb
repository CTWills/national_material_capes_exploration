# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/material_data.csv", encoding="latin-1")

# %%
data.sample()
# Out:
#                     statenme stateabb  ccode  year  irst  \
# 53  United States of America      USA      2  1869  1739
#
#                  irstsource irstnote irstqualitycode irstanomalycode      pec  \
# 53   4th ed., 1998, p. 359.      NaN               A               A  35983.0
#
#     ... upopanomalycode upopgrowth upopgrowthsource     tpop  \
# 53  ...             NaN        NaN              NaN  39051.0
#
#                                            tpopsource tpopnote  \
# 53  Historical Statistics of the United States:  C...      NaN
#
#    tpopqualitycode  tpopanomalycode      cinc version
# 53               A                A  0.108006       4
#
# [1 rows x 34 columns]

# %%
data.shape
# Out:
# (14199, 34)

# %%
object_types = data.dtypes != "object"

# %%
columns = data.columns[object_types]
len(columns)
# Out:
# 12

# %%
data[columns]
# Out:
#        ccode  year  irst        pec  milper  milex   upop  upopanomalycode  \
# 0          2  1816    80  254.00000      17   3823  101.0              NaN
# 1          2  1817    80  277.00000      15   2466  106.0              NaN
# 2          2  1818    90  302.00000      14   1910  112.0              NaN
# 3          2  1819    90  293.00000      13   2301  118.0              NaN
# 4          2  1820   110  303.00000      15   1556  124.0              NaN
# ...      ...   ...   ...        ...     ...    ...    ...              ...
# 14194    990  2003     0   44.54492       0      0    0.0              NaN
# 14195    990  2004     0   42.77610       0      0    0.0              NaN
# 14196    990  2005     0   43.50082       0      0    0.0              NaN
# 14197    990  2006     0   44.62415       0      0    0.0              NaN
# 14198    990  2007     0   44.93124       0      0    0.0              NaN
#
#        upopgrowth    tpop      cinc  version
# ...
